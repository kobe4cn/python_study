# %%
# !uv pip install langchain_community tiktoken langchain-openai tavily-python bs4 
# !uv pip install 'markitdown[all]'
# !uv pip install html2text
# !uv pip install transformers
# !uv pip install langchain-qdrant
# Out:
# Now using Node v24.8.0 (npm 11.6.0) ~/.local/share/nvm/v24.8.0/bin/node
# Audited 5 packages in 13ms
# Now using Node v24.8.0 (npm 11.6.0) ~/.local/share/nvm/v24.8.0/bin/node
# Audited 1 package in 14ms
# Now using Node v24.8.0 (npm 11.6.0) ~/.local/share/nvm/v24.8.0/bin/node
# Audited 1 package in 2ms
# Now using Node v24.8.0 (npm 11.6.0) ~/.local/share/nvm/v24.8.0/bin/node
# Audited 1 package in 4ms
# Now using Node v24.8.0 (npm 11.6.0) ~/.local/share/nvm/v24.8.0/bin/node
# Resolved 34 packages in 4.14s
# ⠹ Preparing packages... (0/1)
# ⠹ Preparing packages... (0/1)--------------     0 B/23.76 KiB
# ⠹ Preparing packages... (0/1)---------- 16.00 KiB/23.76 KiB
# Prepared 1 package in 324ms
# Installed 1 package in 1ms.2.1
#  + langchain-qdrant==0.2.1

# %%
# !uv pip install llama-index
# !uv pip install llama-index-core

# !uv pip install llama-index-llms-openai-like

# !uv pip install llama-index-llms-dashscope
# !uv pip install llama-index-embeddings-dashscope
# Out:
# Now using Node v24.8.0 (npm 11.6.0) ~/.local/share/nvm/v24.8.0/bin/node
# Resolved 82 packages in 7.26s
# ⠹ Preparing packages... (0/14)
# ⠹ Preparing packages... (0/14)----------------     0 B/24.77 KiB
# ⠹ Preparing packages... (0/14)------------ 14.90 KiB/24.77 KiB
# ⠹ Preparing packages... (0/14)------------ 14.90 KiB/24.77 KiB
# llama-index-llms-openai ------------------------------ 14.90 KiB/24.77 KiB
# ⠹ Preparing packages... (0/14)----------------     0 B/315.87 KiB
# llama-index-llms-openai ------------------------------ 14.90 KiB/24.77 KiB
# ⠹ Preparing packages... (0/14)---------------- 14.88 KiB/315.87 KiB
# llama-index-llms-openai ------------------------------ 24.77 KiB/24.77 KiB
# ⠹ Preparing packages... (0/14)---------------- 14.88 KiB/315.87 KiB
# ⠸ Preparing packages... (1/14)---------------- 14.88 KiB/315.87 KiB
# ⠸ Preparing packages... (1/14)---------------- 14.88 KiB/315.87 KiB
# ⠸ Preparing packages... (1/14)---------------- 30.88 KiB/315.87 KiB
# ...
